# %% [markdown]
# # Gold Price Dynamics - Exploratory Analysis
#
# This notebook explores the gold price dataset from Kaggle.

# %% [markdown]
# ## 1. Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Add src to path
import sys
sys.path.append('../src')

from data_processing import load_data, add_features, get_summary_stats
from visualization import plot_price_trend, plot_yearly_comparison

# %matplotlib inline
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")

# %% [markdown]
# ## 2. Load Data
#
# **Before running:** Download the dataset from Kaggle and place it in the `data/` folder.

# %%
# TODO: Update the filename to match your downloaded dataset
df = load_data('../data/gold_price.csv')

print(f"Dataset shape: {df.shape}")
print(f"\nColumns: {list(df.columns)}")
print(f"\nFirst few rows:")
df.head()

# %% [markdown]
# ## 3. Data Overview

# %%
# Get summary statistics
stats = get_summary_stats(df)
print(f"Total records: {stats['total_records']}")
print(f"Date range: {stats['date_range'][0]} to {stats['date_range'][1]}")
print("\nSummary Statistics:")
stats['summary']

# %% [markdown]
# ## 4. Feature Engineering

# %%
# Add engineered features
df = add_features(df)
df.head()

# %% [markdown]
# ## 5. Visualizations

# %%
# Price trend
fig = plot_price_trend(df, save_path='../results/price_trend.png')
plt.show()

# %%
# Yearly comparison
fig = plot_yearly_comparison(df, save_path='../results/yearly_comparison.png')
plt.show()

# %% [markdown]
# ## 6. Next Steps
#
# - [ ] Add correlation heatmap
# - [ ] Build predictive model
# - [ ] Analyze seasonal patterns
# - [ ] Create forecasting model
